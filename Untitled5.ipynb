# %%
import pandas as pd

# %%
df=pd.read_csv('weight.csv')

# %%
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
df=df.drop("Gender",axis=1)

# %%
print('After removing Non numeric columns:')
df
# Out:
# After removing Non numeric columns:
#          Height      Weight
# 0     73.847017  241.893563
# 1     68.781904  162.310473
# 2     74.110105  212.740856
# 3     71.730978  220.042470
# 4     69.881796  206.349801
# ...         ...         ...
# 9995  66.172652  136.777454
# 9996  67.067155  170.867906
# 9997  63.867992  128.475319
# 9998  69.034243  163.852461
# 9999  61.944246  113.649103
#
# [10000 rows x 2 columns]

# %%
# Out:
#          Height      Weight
# 0     73.847017  241.893563
# 1     68.781904  162.310473
# 2     74.110105  212.740856
# 3     71.730978  220.042470
# 4     69.881796  206.349801
# ...         ...         ...
# 9995  66.172652  136.777454
# 9996  67.067155  170.867906
# 9997  63.867992  128.475319
# 9998  69.034243  163.852461
# 9999  61.944246  113.649103
#
# [10000 rows x 2 columns]

# %%
df.boxplot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# C:\Users\PRETHI~1\AppData\Local\Temp/ipykernel_21312/4034180647.py in <module>
# ----> 1 df.boxplot()
#
# ~\anaconda32021\envs\webapp\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     508     **kwargs,
#     509 ):
# --> 510     plot_backend = _get_plot_backend(backend)
#     511     return plot_backend.boxplot_frame(
#     512         self,
#
# ~\anaconda32021\envs\webapp\lib\site-packages\pandas\plotting\_core.py in _get_plot_backend(backend)
#    1847         return _backends[backend]
#    1848
# -> 1849     module = _load_backend(backend)
#    1850     _backends[backend] = module
#    1851     return module
#
# ~\anaconda32021\envs\webapp\lib\site-packages\pandas\plotting\_core.py in _load_backend(backend)
# ...
